# %% [markdown]
# # Question 1

# %% [markdown]
# Using the given MT cars dataset you need to find outlier with Z score

# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as stats
import seaborn as sns
import os
os.chdir("C:\Datasets")

# %%
df= pd.read_csv("mtcars.csv")

# %%
import pandas as pd
mtcars= pd.read_csv("mtcars.csv")
mtcars.index = mtcars.model
mtcars.head()
# Out:
#                                model   mpg  cyl   disp   hp  drat     wt  \
# model
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# model
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2

# %%
mtcars.min()
# Out:
# model    AMC Javelin
# mpg             10.4
# cyl                4
# disp            71.1
# hp                52
# drat            2.76
# wt             1.513
# qsec            14.5
# vs                 0
# am                 0
# gear               3
# carb               1
# dtype: object

# %%
mtcars.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
mtcars.max()
# Out:
# model    Volvo 142E
# mpg            33.9
# cyl               8
# disp            472
# hp              335
# drat           4.93
# wt            5.424
# qsec           22.9
# vs                1
# am                1
# gear              5
# carb              8
# dtype: object

# %%
mtcars.sample(5)
# Out:
#                                model   mpg  cyl   disp   hp  drat     wt  \
# model
# Merc 280C                  Merc 280C  17.8    6  167.6  123  3.92  3.440
# Lotus Europa            Lotus Europa  30.4    4   95.1  113  3.77  1.513
# Chrysler Imperial  Chrysler Imperial  14.7    8  440.0  230  3.23  5.345
# Volvo 142E                Volvo 142E  21.4    4  121.0  109  4.11  2.780
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
#
#                     qsec  vs  am  gear  carb
# model
# Merc 280C          18.90   1   0     4     4
# Lotus Europa       16.90   1   1     5     2
# Chrysler Imperial  17.42   0   0     3     4
# Volvo 142E         18.60   1   1     4     2
# Datsun 710         18.61   1   1     4     1

# %%
from scipy.stats import norm
import numpy as np

plt.hist(df.model,bins=30,rwidth= 0.8, density =True)

plt.ylabel("carb")
# Out:
# Text(0, 0.5, 'carb')

# %%
mtcars.std()
# Out:
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
sns.boxplot(y='carb', data=mtcars)

# %%
df.carb.std()
# Out:
# 1.6151999776318522

# %%
df.carb.mean()
# Out:
# 2.8125

# %%
upper_limit = df.carb.mean() +3*df.carb.std()
upper_limit
# Out:
# 7.658099932895556

# %%
lower_limit=df.carb.mean() -3*df.carb.std()
lower_limit
# Out:
# -2.0330999328955563

# %%
df[(df.carb>upper_limit)| (df.carb<lower_limit)]
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
df[(df.carb<upper_limit)&(df.carb>lower_limit)]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 31     4     2

# %%
df["zscore"]=(df.carb - df.carb.mean())/df.carb.std()
df.head(5)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb    zscore
# 0     4  0.735203
# 1     4  0.735203
# 2     1 -1.122152
# 3     1 -1.122152
# 4     2 -0.503034

# %%
(4-2.8125)/1.6151999776318522
# Out:
# 0.7352030810086251

# %%
df[df["zscore"]>3]
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5
#
#     carb    zscore
# 30     8  3.211677

# %%
df[df["zscore"]<3]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb    zscore
# 0      4     4  0.735203
# 1      4     4  0.735203
# 2      4     1 -1.122152
# 3      3     1 -1.122152
# 4      3     2 -0.503034
# 5      3     1 -1.122152
# 6      3     4  0.735203
# 7      4     2 -0.503034
# 8      4     2 -0.503034
# 9      4     4  0.735203
# 10     4     4  0.735203
# 11     3     3  0.116085
# 12     3     3  0.116085
# 13     3     3  0.116085
# 14     3     4  0.735203
# 15     3     4  0.735203
# 16     3     4  0.735203
# 17     4     1 -1.122152
# 18     4     2 -0.503034
# 19     4     1 -1.122152
# 20     3     1 -1.122152
# 21     3     2 -0.503034
# 22     3     2 -0.503034
# 23     3     4  0.735203
# 24     3     2 -0.503034
# 25     4     1 -1.122152
# 26     5     2 -0.503034
# 27     5     2 -0.503034
# 28     5     4  0.735203
# 29     5     6  1.973440
# 31     4     2 -0.503034

# %%
df_no_outliers = df[(df.zscore>-3)&(df.zscore<3)]
df_no_outliers.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb    zscore
# 0     4  0.735203
# 1     4  0.735203
# 2     1 -1.122152
# 3     1 -1.122152
# 4     2 -0.503034

# %% [markdown]
# # Question 2

# %% [markdown]
# Using the Boston set from sklearn , find outlier and treat them

# %%
import os

os.chdir('C:\Datasets')

# %%
df= pd.read_csv("bostoncars.csv")

# %%
import pandas as pd
bostoncars= pd.read_csv("bostoncars.csv")
bostoncars.index = bostoncars.Car
bostoncars.head()
# Out:
#                    Car       Model  Volume  Weight  CO2
# Car
# Toyota          Toyota        Aygo    1000     790   99
# Mitsubishi  Mitsubishi  Space Star    1200    1160   95
# Skoda            Skoda      Citigo    1000     929   95
# Fiat              Fiat         500     900     865   90
# Mini              Mini      Cooper    1500    1140  105

# %%
bostoncars.describe()
# Out:
#             Volume       Weight         CO2
# count    36.000000    36.000000   36.000000
# mean   1611.111111  1292.277778  102.027778
# std     388.975047   242.123889    7.454571
# min     900.000000   790.000000   90.000000
# 25%    1475.000000  1117.250000   97.750000
# 50%    1600.000000  1329.000000   99.000000
# 75%    2000.000000  1418.250000  105.000000
# max    2500.000000  1746.000000  120.000000

# %%
bostoncars.tail()
# Out:
#                Car   Model  Volume  Weight  CO2
# Car
# Volvo        Volvo    XC70    2000    1746  117
# Ford          Ford   B-Max    1600    1235  104
# BMW            BMW       2    1600    1390  108
# Opel          Opel  Zafira    1600    1405  109
# Mercedes  Mercedes     SLK    2500    1395  120

# %%
bostoncars.min()
# Out:
# Car       Audi
# Model        1
# Volume     900
# Weight     790
# CO2         90
# dtype: object

# %%
from scipy.stats import norm
import numpy as np
# %matplotlib inline
bostoncars.hist(column="CO2",figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000272A6025B88>]],
#       dtype=object)

# %%
sns.boxplot(y='CO2', data=bostoncars)

# %%
df.CO2.std()
# Out:
# 7.454571410928659

# %%
df.CO2.mean()
# Out:
# 102.02777777777777

# %%
upper_limit = df.CO2.mean() +2*df.CO2.std()
upper_limit
# Out:
# 116.93692059963509

# %%
lower_limit = df.CO2.mean()-3*df.CO2.std()
lower_limit
# Out:
# 79.66406354499179

# %%
df["zscore"]=(df.CO2- df.CO2.mean())/df.CO2.std()
df.head(5)
# Out:
#           Car       Model  Volume  Weight  CO2    zscore
# 0      Toyota        Aygo    1000     790   99 -0.406164
# 1  Mitsubishi  Space Star    1200    1160   95 -0.942747
# 2       Skoda      Citigo    1000     929   95 -0.942747
# 3        Fiat         500     900     865   90 -1.613477
# 4        Mini      Cooper    1500    1140  105  0.398711

# %%
df[df["zscore"]<2]
# Out:
#            Car       Model  Volume  Weight  CO2    zscore
# 0       Toyota        Aygo    1000     790   99 -0.406164
# 1   Mitsubishi  Space Star    1200    1160   95 -0.942747
# 2        Skoda      Citigo    1000     929   95 -0.942747
# 3         Fiat         500     900     865   90 -1.613477
# 4         Mini      Cooper    1500    1140  105  0.398711
# 5           VW         Up!    1000     929  105  0.398711
# 6        Skoda       Fabia    1400    1109   90 -1.613477
# 7     Mercedes     A-Class    1500    1365   92 -1.345185
# 8         Ford      Fiesta    1500    1112   98 -0.540310
# 9         Audi          A1    1600    1150   99 -0.406164
# 10     Hyundai         I20    1100     980   99 -0.406164
# 11      Suzuki       Swift    1300     990  101 -0.137872
# 12        Ford      Fiesta    1000    1112   99 -0.406164
# 13       Honda       Civic    1600    1252   94 -1.076893
# 14      Hundai         I30    1600    1326   97 -0.674456
# 15        Opel       Astra    1600    1330   97 -0.674456
# 16         BMW           1    1600    1365   99 -0.406164
# 17       Mazda           3    2200    1280  104  0.264565
# 18       Skoda       Rapid    1600    1119  104  0.264565
# 19        Ford       Focus    2000    1328  105  0.398711
# 20        Ford      Mondeo    1600    1584   94 -1.076893
# 21        Opel    Insignia    2000    1428   99 -0.406164
# 22    Mercedes     C-Class    2100    1365   99 -0.406164
# 23       Skoda     Octavia    1600    1415   99 -0.406164
# 24       Volvo         S60    2000    1415   99 -0.406164
# 25    Mercedes         CLA    1500    1465  102 -0.003726
# 26        Audi          A4    2000    1490  104  0.264565
# 27        Audi          A6    2000    1725  114  1.606024
# 28       Volvo         V70    1600    1523  109  0.935295
# 29         BMW           5    2000    1705  114  1.606024
# 30    Mercedes     E-Class    2100    1605  115  1.740170
# 32        Ford       B-Max    1600    1235  104  0.264565
# 33         BMW           2    1600    1390  108  0.801149
# 34        Opel      Zafira    1600    1405  109  0.935295

# %%
df[df["zscore"]>2]
# Out:
#          Car Model  Volume  Weight  CO2    zscore
# 31     Volvo  XC70    2000    1746  117  2.008462
# 35  Mercedes   SLK    2500    1395  120  2.410899

# %%
df[(df.zscore<2) |(df.zscore>2)]
# Out:
#            Car       Model  Volume  Weight  CO2    zscore
# 0       Toyota        Aygo    1000     790   99 -0.406164
# 1   Mitsubishi  Space Star    1200    1160   95 -0.942747
# 2        Skoda      Citigo    1000     929   95 -0.942747
# 3         Fiat         500     900     865   90 -1.613477
# 4         Mini      Cooper    1500    1140  105  0.398711
# 5           VW         Up!    1000     929  105  0.398711
# 6        Skoda       Fabia    1400    1109   90 -1.613477
# 7     Mercedes     A-Class    1500    1365   92 -1.345185
# 8         Ford      Fiesta    1500    1112   98 -0.540310
# 9         Audi          A1    1600    1150   99 -0.406164
# 10     Hyundai         I20    1100     980   99 -0.406164
# 11      Suzuki       Swift    1300     990  101 -0.137872
# 12        Ford      Fiesta    1000    1112   99 -0.406164
# 13       Honda       Civic    1600    1252   94 -1.076893
# 14      Hundai         I30    1600    1326   97 -0.674456
# 15        Opel       Astra    1600    1330   97 -0.674456
# 16         BMW           1    1600    1365   99 -0.406164
# 17       Mazda           3    2200    1280  104  0.264565
# 18       Skoda       Rapid    1600    1119  104  0.264565
# 19        Ford       Focus    2000    1328  105  0.398711
# 20        Ford      Mondeo    1600    1584   94 -1.076893
# 21        Opel    Insignia    2000    1428   99 -0.406164
# 22    Mercedes     C-Class    2100    1365   99 -0.406164
# 23       Skoda     Octavia    1600    1415   99 -0.406164
# 24       Volvo         S60    2000    1415   99 -0.406164
# 25    Mercedes         CLA    1500    1465  102 -0.003726
# 26        Audi          A4    2000    1490  104  0.264565
# 27        Audi          A6    2000    1725  114  1.606024
# 28       Volvo         V70    1600    1523  109  0.935295
# 29         BMW           5    2000    1705  114  1.606024
# 30    Mercedes     E-Class    2100    1605  115  1.740170
# 31       Volvo        XC70    2000    1746  117  2.008462
# 32        Ford       B-Max    1600    1235  104  0.264565
# 33         BMW           2    1600    1390  108  0.801149
# 34        Opel      Zafira    1600    1405  109  0.935295
# 35    Mercedes         SLK    2500    1395  120  2.410899

# %%
df_no_outliers =df[(df.zscore>-2)&(df.zscore<2)]
df_no_outliers.head()
# Out:
#           Car       Model  Volume  Weight  CO2    zscore
# 0      Toyota        Aygo    1000     790   99 -0.406164
# 1  Mitsubishi  Space Star    1200    1160   95 -0.942747
# 2       Skoda      Citigo    1000     929   95 -0.942747
# 3        Fiat         500     900     865   90 -1.613477
# 4        Mini      Cooper    1500    1140  105  0.398711

# %%
df.shape[0]-df_no_outliers.shape[0]
# Out:
# 2
